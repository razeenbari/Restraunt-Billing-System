# %%
#importing libraries
import random
import time
import datetime
import tkinter.messagebox
from tkinter import *


#for creating main window
root = Tk()
#Giving main window a title
root.title("Restaurant Billing System")
#Giving window a default size.
root.geometry('1500x1200')

#===========================Frames=========================
#making a frame for heading.
top= Frame(root,relief=RIDGE)
top.pack(side=TOP)
R_name= Label(top,text='Restaurant Billing System', font=('aerolite',36,'italic'),fg='#2ECC71')
R_name.pack(side=TOP)
Greeting=Label(top,text='"Courteous treatment will make a customer a walking advertisement" - JAMES CASH PENNY',font=('Courier',14,'italic'))
Greeting.pack(side=BOTTOM)
#for menu
Item= Frame(root,relief=RIDGE)
Item.pack(side=TOP)
food = Frame(Item,relief=GROOVE) 
food.pack(side=LEFT)
drinks = Frame(Item,relief=GROOVE)
drinks.pack(side=RIGHT)
total= Frame(Item,relief=GROOVE)
total.pack(side=BOTTOM)
#for billing
billing= Frame(root,relief=RIDGE)
billing.pack(side=RIGHT)
recipt= Frame(billing,relief=GROOVE)
recipt.pack(side=TOP)
recipt_button= Frame(billing,relief=GROOVE)
recipt_button.pack(side=BOTTOM)
#=============================Variable=============================

var1=IntVar()
var2=IntVar()
var3=IntVar()
var4=IntVar()
var5=IntVar()
var6=IntVar()
var7=IntVar()
var8=IntVar()
var9=IntVar()
var10=IntVar()
var11=IntVar()
var12=IntVar()
var13=IntVar()
var14=IntVar()
var15=IntVar()
var16=IntVar()


DateofOrder= StringVar()
Recipt_ref= StringVar()
TaxPaid= StringVar()
Subtotal=StringVar()
Totalcost= StringVar()
Costofdishes = StringVar()
Costofdrinks= StringVar()
Servicetax= StringVar()

text_input = StringVar()
operator=""

C_Pepsi = StringVar()
C_Coke_cola = StringVar()
C_Marinda = StringVar()
C_Dew = StringVar()
C_7up = StringVar()
C_String = StringVar()
C_Fanta = StringVar()
C_Sprite = StringVar()

D_Chickenbiryani = StringVar()
D_Chickenkarahi = StringVar()
D_Muttonkarahi = StringVar()
D_Beefkarahi = StringVar()
D_Qeema= StringVar()
D_Sajji = StringVar()
D_Chargha = StringVar()
D_Paratha = StringVar()

C_Pepsi.set("0")
C_Coke_cola.set("0")
C_Marinda.set("0")
C_Dew.set("0")
C_7up.set("0")
C_String.set("0")
C_Fanta.set("0")
C_Sprite.set("0")

D_Chickenbiryani.set("0")
D_Chickenkarahi.set("0")
D_Muttonkarahi.set("0")
D_Beefkarahi.set("0")
D_Qeema.set("0")
D_Sajji.set("0")
D_Chargha.set("0")
D_Paratha.set("0")

DateofOrder.set(time.strftime("%d/%m/%y"))

#====================== Decleration of Function ====================
class function:
    def p_Exit(self):
        p_Exit = tkinter.messagebox.askyesno("Exit","Are you sure to exit? ")
        if p_Exit > 0:
            root.destroy()
            return
    def p_reset(self):
        C_Pepsi.set("0")
        C_Coke_cola.set("0")
        C_Marinda.set("0")
        C_Dew.set("0")
        C_7up.set("0")
        C_String.set("0")
        C_Fanta.set("0")
        C_Sprite.set("0")
        
        D_Chickenbiryani.set("0")
        D_Chickenkarahi.set("0")
        D_Muttonkarahi.set("0")
        D_Beefkarahi.set("0")
        D_Qeema.set("0")
        D_Sajji.set("0")
        D_Chargha.set("0")
        D_Paratha.set("0")
        
        TaxPaid.set("0")
        Subtotal.set("0")
        Totalcost.set("0")
        Costofdishes.set("0")
        Costofdrinks.set("0")
        Servicetax.set('0')
       
        var1.set(0)
        var2.set(0)
        var3.set(0)
        var4.set(0)
        var5.set(0)
        var6.set(0)
        var7.set(0)
        var8.set(0)
        var9.set(0)
        var10.set(0)
        var11.set(0)
        var12.set(0)
        var13.set(0)
        var14.set(0)
        var15.set(0)
        var16.set(0)
       
        txtPepsi.configure(state=DISABLED)
        txtCoke_cola.configure(state=DISABLED)
        txtMarinda.configure(state=DISABLED)
        txtDew.configure(state=DISABLED)
        txt7up.configure(state=DISABLED)
        txtString.configure(state=DISABLED)
        txtFanta.configure(state=DISABLED)
        txtSprite.configure(state=DISABLED)
        txtChickenbiryani.configure(state=DISABLED)
        txtChickenkarahi.configure(state=DISABLED)
        txtMuttonkarahi.configure(state=DISABLED)
        txtBeefkarahi.configure(state=DISABLED)
        txtQeema.configure(state=DISABLED)
        txtSajji.configure(state=DISABLED)
        txtChargha.configure(state=DISABLED)
        txtParatha.configure(state=DISABLED)
        
    def CostofItem(self):
        Item1=float(C_Pepsi.get())
        Item2=float(C_Coke_cola.get())
        Item3=float(C_Marinda.get())
        Item4=float(C_Dew.get())
        Item5=float(C_7up.get())
        Item6=float(C_String.get())
        Item7=float(C_Fanta.get())
        Item8=float(C_Sprite.get())
        
        Item9=float(D_Chickenbiryani.get())
        Item10=float(D_Chickenkarahi.get())
        Item11=float(D_Muttonkarahi.get())
        Item12=float(D_Beefkarahi.get())
        Item13=float(D_Qeema.get())
        Item14=float(D_Sajji.get())
        Item15=float(D_Chargha.get())
        Item16=float(D_Paratha.get())
        
        PriceofDrinks=((Item1 * 35 ) + (Item2 * 35) + (Item3 * 35) + (Item4 * 35)
                       + (Item5 * 35) + (Item6 * 40) + (Item7 * 35) + (Item8 * 35))
        PriceofDishes=((Item9 * 120) + (Item10 * 300) + (Item11 * 500) + (Item12 * 400)
                       + (Item13 * 250) + (Item14 * 650) + (Item15 * 350) + (Item16 * 30))

        DrinksPrice="Rs", str('%.2f'%(PriceofDrinks))
        DishesPrice="Rs", str('%.2f'%(PriceofDishes))
        Costofdishes.set(DishesPrice)
        Costofdrinks.set(DrinksPrice)
        SC="Rs", str('%.2f'%(2.5))
        Servicetax.set(SC)

        SubTotalofITEMS="Rs", str('%.2f'%(PriceofDrinks + PriceofDishes + 2.5))
        Subtotal.set(SubTotalofITEMS)

        Tax="Rs", str('%.2f'%((PriceofDrinks + PriceofDishes + 2.5)*0.17))
        TaxPaid.set(Tax)
        TT=((PriceofDrinks + PriceofDishes + 2.5) *0.17)
        TC="Rs", str('%.2f'%(PriceofDishes + PriceofDrinks + 2.5 + TT))
        Totalcost.set(TC)
        
class meal(function):
    def chkPepsi(self):
        if(var1.get()==1):
            txtPepsi.configure(state= NORMAL)
            txtPepsi.focus()
            txtPepsi.delete('0', END)
            C_Pepsi.set("")
        elif(var1.get()==0):
            txtPepsi.configure(state= DISABLED)
            C_Pepsi.set("0")
    def chkCoke_cola(self):
        if(var2.get()==1):
            txtCoke_cola.configure(state= NORMAL)
            txtCoke_cola.focus()
            txtCoke_cola.delete('0', END)
            C_Coke_cola.set("")
        elif(var2.get()==0):
            txtCoke_cola.configure(state= DISABLED)
            C_Coke_cola.set("0")
    def chkMarinda(self):
        if(var3.get()==1):
            txtMarinda.configure(state= NORMAL)
            txtMarinda.focus()
            txtMarinda.delete('0', END)
            C_Marinda.set("")
        elif(var3.get()==0):
            txtMarinda.configure(state= DISABLED)
            C_Marinda.set("0")
    def chkDew(self):
        if(var4.get()==1):
            txtDew.configure(state= NORMAL)
            txtDew.focus()
            txtDew.delete('0', END)
            C_Dew.set("")
        elif(var4.get()==0):
            txtDew.configure(state= DISABLED)
            C_Dew.set("0")
    def chk7up(self):
        if(var5.get()==1):
            txt7up.configure(state= NORMAL)
            txt7up.focus()
            txt7up.delete('0', END)
            C_7up.set("")
        elif(var5.get()==0):
            txt7up.configure(state= DISABLED)
            C_7up.set("0")
    def chkString(self):
        if(var6.get()==1):
            txtString.configure(state= NORMAL)
            txtString.focus()
            txtString.delete('0', END)
            C_String.set("")
        elif(var6.get()==0):
            txtString.configure(state= DISABLED)
            C_String.set("0")
    def chkFanta(self):
        if(var7.get()==1):
            txtFanta.configure(state= NORMAL)
            txtFanta.focus()
            txtFanta.delete('0', END)
            C_Fanta.set("")
        elif(var7.get()==0):
            txtFanta.configure(state= DISABLED)
            C_Fanta.set("0")
    def chkSprite(self):
        if(var8.get()==1):
            txtSprite.configure(state= NORMAL)
            txtSprite.focus()
            txtSprite.delete('0', END)
            C_Sprite.set("")
        elif(var8.get()==0):
            txtSprite.configure(state= DISABLED)
            C_Sprite.set("0")
    def chkChickenbiryani(self):
        if(var9.get()==1):
            txtChickenbiryani.configure(state= NORMAL)
            txtChickenbiryani.focus()
            txtChickenbiryani.delete('0', END)
            D_Chickenbiryani.set("")
        elif(var9.get()==0):
            txtChickenbiryani.configure(state= DISABLED)
            D_Chickenbiryani.set("0")
    def chkChickenkarahi(self):
        if(var10.get()==1):
            txtChickenkarahi.configure(state= NORMAL)
            txtChickenkarahi.focus()
            txtChickenkarahi.delete('0', END)
            D_Chickenkarahi.set("")
        elif(var10.get()==0):
            txtChickenkarahi.configure(state= DISABLED)
            D_Chickenkarahi.set("0")
    def chkMuttonkarahi(self):
        if(var11.get()==1):
            txtMuttonkarahi.configure(state= NORMAL)
            txtMuttonkarahi.focus()
            txtMuttonkarahi.delete('0', END)
            D_Muttonkarahi.set("")
        elif(var11.get()==0):
            txtMuttonkarahi.configure(state= DISABLED)
            D_Muttonkarahi.set("0")
    def chkBeefkarahi(self):
        if(var12.get()==1):
            txtBeefkarahi.configure(state= NORMAL)
            txtBeefkarahi.focus()
            txtBeefkarahi.delete('0', END)
            D_Beefkarahi.set("")
        elif(var12.get()==0):
            txtBeefkarahi.configure(state= DISABLED)
            D_Beefkarahi.set("0")
    def chkQeema(self):
        if(var13.get()==1):
            txtQeema.configure(state= NORMAL)
            txtQeema.focus()
            txtQeema.delete('0', END)
            D_Qeema.set("")
        elif(var13.get()==0):
            txtQeema.configure(state= DISABLED)
            D_Qeema.set("0")
    def chkSajji(self):
        if(var14.get()==1):
            txtSajji.configure(state= NORMAL)
            txtSajji.focus()
            txtSajji.delete('0', END)
            D_Sajji.set("")
        elif(var14.get()==0):
            txtSajji.configure(state= DISABLED)
            D_Sajji.set("0")
    def chkChargha(self):
        if(var15.get()==1):
            txtChargha.configure(state= NORMAL)
            txtChargha.focus()
            txtChargha.delete('0', END)
            D_Chargha.set("")
        elif(var15.get()==0):
            txtChargha.configure(state= DISABLED)
            D_Chargha.set("0")
    def chkParatha(self):
        if(var16.get()==1):
            txtParatha.configure(state= NORMAL)
            txtParatha.focus()
            txtParatha.delete('0', END)
            D_Paratha.set("")
        elif(var16.get()==0):
            txtParatha.configure(state= DISABLED)
            D_Paratha.set("0")
class printrecipt(meal):
    def Receipt(self):
        txtReceipt.delete("1.0",END)
        a= random.randint(1,1000)
        r_ref= str(a)
        Recipt_ref.set("BILL" + r_ref)
        
        txtReceipt.insert(END, 'Receipt Ref:\t\t\t' + Recipt_ref.get() + "\t" + DateofOrder.get() + "\n")
        txtReceipt.insert(END, 'Item:\t\t\t' + "No of Items\n")
        txtReceipt.insert(END, 'Pepsi: \t\t\t\t' + C_Pepsi.get() + "\n")
        txtReceipt.insert(END, 'Coka Cola: \t\t\t\t' + C_Coke_cola.get() + "\n")
        txtReceipt.insert(END, 'Marinda: \t\t\t\t' + C_Marinda.get() + "\n")
        txtReceipt.insert(END, 'Dew: \t\t\t\t' + C_Dew.get() + "\n")
        txtReceipt.insert(END, '7up: \t\t\t\t' + C_7up.get() + "\n")
        txtReceipt.insert(END, 'String: \t\t\t\t' + C_String.get() + "\n")
        txtReceipt.insert(END, 'Fanta: \t\t\t\t' + C_Fanta.get() + "\n")
        txtReceipt.insert(END, 'Sprite: \t\t\t\t' + C_Sprite.get() + "\n")
        txtReceipt.insert(END, 'Chicken Biryani: \t\t\t\t' + D_Chickenbiryani.get() + "\n")
        txtReceipt.insert(END, 'Chicken Karahi: \t\t\t\t' + D_Chickenkarahi.get() + "\n")
        txtReceipt.insert(END, 'Mutton Karahi: \t\t\t\t' + D_Muttonkarahi.get() + "\n")
        txtReceipt.insert(END, 'Beef Karahi: \t\t\t\t' + D_Beefkarahi.get() + "\n")
        txtReceipt.insert(END, 'Qeema: \t\t\t\t' + D_Qeema.get() + "\n")
        txtReceipt.insert(END, 'Sajji: \t\t\t\t' + D_Sajji.get() + "\n")
        txtReceipt.insert(END, 'Chargha: \t\t\t\t' + D_Chargha.get() + "\n")
        txtReceipt.insert(END, 'Paratha: \t\t\t\t' + D_Paratha.get() + "\n")

    

objectfun=printrecipt()
        
#===========================Checkbox for drinks==========================

Pepsi=Checkbutton(drinks, text="Pepsi",variable=var1, onvalue=1, offvalue=0,font=('aerolite',16,'italic')
                  ,command=objectfun.chkPepsi).grid(row=0,sticky=W)
Coke_cola=Checkbutton(drinks, text="Coka Cola", variable=var2, onvalue=1, offvalue=0,font=('aerolite',16,'italic')
                    ,command=objectfun.chkCoke_cola).grid(row=1,sticky=W)
Marinda=Checkbutton(drinks, text="Marinda",variable=var3, onvalue=1, offvalue=0,font=('aerolite',16,'italic')
                    ,command=objectfun.chkMarinda).grid(row=2,sticky=W)
Dew=Checkbutton(drinks, text="Dew",variable=var4, onvalue=1, offvalue=0,font=('aerolite',16,'italic')
                ,command=objectfun.chkDew).grid(row=3,sticky=W)
up7=Checkbutton(drinks, text="7up",variable=var5, onvalue=1, offvalue=0,font=('aerolite',16,'italic')
                ,command=objectfun.chk7up).grid(row=4,sticky=W)
String=Checkbutton(drinks, text="String",variable=var6, onvalue=1, offvalue=0,font=('aerolite',16,'italic')
                   ,command=objectfun.chkString).grid(row=5,sticky=W)
Fanta=Checkbutton(drinks, text="Fanta",variable=var7, onvalue=1, offvalue=0,font=('aerolite',16,'italic')
                  ,command=objectfun.chkFanta).grid(row=6,sticky=W)
Sprite=Checkbutton(drinks, text="Sprite",variable=var8, onvalue=1, offvalue=0,font=('aerolite',16,'italic')
                   ,command=objectfun.chkSprite).grid(row=7,sticky=W)

#===========================Entry box for drinks=========================

txtPepsi= Entry(drinks,font=('aerolite',16,'italic'),bd=8, width=6, justify=LEFT, state= DISABLED, textvariable=C_Pepsi)
txtPepsi.grid(row=0,column=1)
txtCoke_cola= Entry(drinks,font=('aerolite',16,'italic'),bd=8, width=6, justify=LEFT, state= DISABLED, textvariable=C_Coke_cola)
txtCoke_cola.grid(row=1,column=1)
txtMarinda= Entry(drinks,font=('aerolite',16,'italic'),bd=8, width=6, justify=LEFT, state= DISABLED, textvariable=C_Marinda)
txtMarinda.grid(row=2,column=1)
txtDew= Entry(drinks,font=('aerolite',16,'italic'),bd=8, width=6, justify=LEFT, state= DISABLED, textvariable=C_Dew)
txtDew.grid(row=3,column=1)
txt7up= Entry(drinks,font=('aerolite',16,'italic'),bd=8, width=6, justify=LEFT, state= DISABLED, textvariable=C_7up)
txt7up.grid(row=4,column=1)
txtString= Entry(drinks,font=('aerolite',16,'italic'),bd=8, width=6, justify=LEFT, state= DISABLED, textvariable=C_String)
txtString.grid(row=5,column=1)
txtFanta= Entry(drinks,font=('aerolite',16,'italic'),bd=8, width=6, justify=LEFT, state= DISABLED, textvariable=C_Fanta)
txtFanta.grid(row=6,column=1)
txtSprite= Entry(drinks,font=('aerolite',16,'italic'),bd=8, width=6, justify=LEFT, state= DISABLED, textvariable=C_Sprite)
txtSprite.grid(row=7,column=1)
        
#=============================Checkbox for dishes===============================

Chickenbiryani=Checkbutton(food, text='Chicken Biryani', variable=var9, onvalue=1, offvalue=0, font=('aerolite',16,'italic')
                , command=objectfun.chkChickenbiryani).grid(row=0,sticky=W)
Chickenkarahi=Checkbutton(food, text='Chicken Karahi', variable=var10, onvalue=1, offvalue=0, font=('aerolite',16,'italic')
                  , command=objectfun.chkChickenkarahi).grid(row=1,sticky=W)
Muttonkarahi=Checkbutton(food, text='Mutton Karahi', variable=var11, onvalue=1, offvalue=0, font=('aerolite',16,'italic')
                  ,command=objectfun.chkMuttonkarahi).grid(row=2,sticky=W)
Beefkarahi=Checkbutton(food, text='Beef Karahi', variable=var12, onvalue=1, offvalue=0, font=('aerolite',16,'italic')
                  , command=objectfun.chkBeefkarahi).grid(row=3,sticky=W)
Qeema=Checkbutton(food, text='Qeema', variable=var13, onvalue=1, offvalue=0, font=('aerolite',16,'italic')
                  , command=objectfun.chkQeema).grid(row=4,sticky=W)
Sajji=Checkbutton(food, text='Sajji', variable=var14, onvalue=1, offvalue=0, font=('aerolite',16,'italic')
                  , command=objectfun.chkSajji).grid(row=5,sticky=W)
Chargha=Checkbutton(food, text='Chargha', variable=var15, onvalue=1, offvalue=0, font=('aerolite',16,'italic')
                  , command=objectfun.chkChargha).grid(row=6,sticky=W)
Paratha=Checkbutton(food, text='Paratha', variable=var16, onvalue=1, offvalue=0, font=('aerolite',16,'italic')
                  , command=objectfun.chkParatha).grid(row=7,sticky=W)
        
#====================================Entrybox for chicken============================

txtChickenbiryani= Entry(food,font=('aerolite',16,'italic'),bd=8, width=10, justify=LEFT, state= DISABLED, textvariable=D_Chickenbiryani)
txtChickenbiryani.grid(row=0,column=1)
txtChickenkarahi= Entry(food,font=('aerolite',16,'italic'),bd=8, width=10, justify=LEFT, state= DISABLED, textvariable=D_Chickenkarahi)
txtChickenkarahi.grid(row=1,column=1)
txtMuttonkarahi= Entry(food,font=('aerolite',16,'italic'),bd=8, width=10, justify=LEFT, state= DISABLED, textvariable=D_Muttonkarahi)
txtMuttonkarahi.grid(row=2,column=1)
txtBeefkarahi= Entry(food,font=('aerolite',16,'italic'),bd=8, width=10, justify=LEFT, state= DISABLED, textvariable=D_Beefkarahi)
txtBeefkarahi.grid(row=3,column=1)
txtQeema= Entry(food,font=('aerolite',16,'italic'),bd=8, width=10, justify=LEFT, state= DISABLED, textvariable=D_Qeema)
txtQeema.grid(row=4,column=1)
txtSajji= Entry(food,font=('aerolite',16,'italic'),bd=8, width=10, justify=LEFT, state= DISABLED, textvariable=D_Sajji)
txtSajji.grid(row=5,column=1)
txtChargha= Entry(food,font=('aerolite',16,'italic'),bd=8, width=10, justify=LEFT, state= DISABLED, textvariable=D_Chargha)
txtChargha.grid(row=6,column=1)
txtParatha= Entry(food,font=('aerolite',16,'italic'),bd=8, width=10, justify=LEFT, state= DISABLED, textvariable=D_Paratha)
txtParatha.grid(row=7,column=1)
        
#================================ TOTAL COST OF FOOD =================================       

LCDrink =Label(total, font=('arial',14,'bold'),text='Cost of Drinks\t',fg='black')
LCDrink.grid(row=0,column=0, sticky=W)
TCDrink= Entry(total, width=40, bg='white', bd=7, font=('arial',7,'bold'), justify=RIGHT, textvariable=Costofdrinks)
TCDrink.grid(row=0, column=1)

LCDishes =Label(total, font=('arial',14,'bold'),text='Cost of Dishes\t',fg='black')
LCDishes.grid(row=1,column=0, sticky=W)
TCDishes= Entry(total, width=40, bg='white', bd=7, font=('arial',7,'bold'), justify=RIGHT, textvariable=Costofdishes)
TCDishes.grid(row=1, column=1)

LSC =Label(total, font=('arial',14,'bold'),text='Service Charge\t',fg='black')
LSC.grid(row=2,column=0, sticky=W)
TSC= Entry(total, bg='white',width=40, bd=7, font=('arial',7,'bold'), justify=RIGHT, textvariable=Servicetax)
TSC.grid(row=2, column=1)
        
#============================== Amount Payed =============================

LPT =Label(total, font=('arial',14,'bold'),text='\tPaid Tax',fg='black')
LPT.grid(row=0,column=2, sticky=W)
TPT = Entry(total, width=40, bg='white', bd=7, font=('arial',7,'bold'), justify=RIGHT, textvariable=TaxPaid)
TPT.grid(row=0, column=3)

LST =Label(total, font=('arial',14,'bold'),text='\tSub Total',fg='black')
LST.grid(row=1,column=2, sticky=W)
TST= Entry(total, width=40, bg='white', bd=7, font=('arial',7,'bold'), justify=RIGHT, textvariable=Subtotal)
TST.grid(row=1, column=3)

LTC =Label(total, font=('arial',14,'bold'),text='\tTotal Cost',fg='black')
LTC.grid(row=2,column=2, sticky=W)
TTC= Entry(total, width=40, bg='white', bd=7, font=('arial',7,'bold'), justify=RIGHT, textvariable=Totalcost)
TTC.grid(row=2, column=3)


#======================================= RECEIPT =============================

txtReceipt= Text(recipt, width=46, height=12, bg='white', bd=4, font=('arial',12,'bold'))
txtReceipt.grid(row=0, column=0)

#====================================== RECEIPT BUTTONS ===========================

btnTotal=Button(recipt_button, padx=16, pady=1, bd=7, fg='black', font=('arial',16,'bold'),
                width=4, text="Total", bg="Powder Blue", command=objectfun.CostofItem).grid(row=0,column=0)
btnReceipt=Button(recipt_button, padx=16, pady=1, bd=7, fg='black', font=('arial',16,'bold'),
                width=4, text="Receipt", bg="Powder Blue", command=objectfun.Receipt).grid(row=0,column=1)
btnReset=Button(recipt_button, padx=16, pady=1, bd=7, fg='black', font=('arial',16,'bold'),
                width=4, text="Reset", bg="Powder Blue", command=objectfun.p_reset).grid(row=0,column=2)
btnExit=Button(recipt_button, padx=16, pady=1, bd=7, fg='black', font=('arial',16,'bold'),
                width=4, text="Exit", bg="Powder Blue", command=objectfun.p_Exit).grid(row=0,column=3)



        
        
        
         

root.mainloop()
